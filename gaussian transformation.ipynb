# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)
import scipy.stats as stats

# %%
data=pd.read_csv(r"C:\Users\user\Desktop\Data sets\train_sales.csv",usecols=['battery_power','ram','mobile_wt'])

# %%
data.head()
# Out:
#    battery_power  mobile_wt   ram
# 0            842        188  2549
# 1           1021        136  2631
# 2            563        145  2603
# 3            615        131  2769
# 4           1821        141  1411

# %%
data.shape
# Out:
# (2000, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   mobile_wt      2000 non-null   int64
#  2   ram            2000 non-null   int64
# dtypes: int64(3)
# memory usage: 47.0 KB

# %%
np.sum(data.isnull())
# Out:
# battery_power    0
# mobile_wt        0
# ram              0
# dtype: int64

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000163C94DDF10>,
# ...
#       dtype=object)

# %%
sns.distplot(data['ram'],kde=True)

# %%
sns.distplot(data['mobile_wt'],kde=True)

# %%
sns.distplot(data['battery_power'],kde=True)

# %%
def diagnostic_plots(df, variable):
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
def diagnostic_plots(data,variables):
    plt.figure(figsize=(15,7))
    plt.subplot(1,2,1)
    data[variables].hist()
    plt.subplot(1,2,2)
    stats.probplot(data[variables],dist='norm',plot=plt)
    plt.show()

# %%
diagnostic_plots(data,'ram')

# %%
diagnostic_plots(data,'battery_power')

# %%
diagnostic_plots(data,'mobile_wt')

# %%
data['Log_ram']=np.log(data['ram']+1)
diagnostic_plots(data,'Log_ram')

# %%
data['Log_power']=np.log(data['battery_power']+1)
diagnostic_plots(data,'Log_power')

# %%
data.head()
# Out:
#    battery_power  mobile_wt   ram   Log_ram  Log_power
# 0            842        188  2549  7.843849   6.736967
# 1           1021        136  2631  7.875499   6.929517
# 2            563        145  2603  7.864804   6.335054
# 3            615        131  2769  7.926603   6.423247
# 4           1821        141  1411  7.252762   7.507690
